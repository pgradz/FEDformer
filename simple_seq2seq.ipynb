# %%
import torch

# %%
outputs = torch.zeros(32, 12, 1)

# %%
outputs.size()
# Out:
# torch.Size([32, 12, 1])

# %%
results = torch.rand(32, 1,1)

# %%
results.size()
# Out:
# torch.Size([32, 1, 1])

# %%
outputs[:, 1, :] = results
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 outputs[:, 1, :] = results
#
# RuntimeError: expand(torch.FloatTensor{[32, 1, 1]}, size=[32, 1]): the number of sizes provided (2) must be greater or equal to the number of dimensions in the tensor (3)

# %%
outputs[:, 1, :].size()
# Out:
# torch.Size([32, 1])

# %%
outputs[:, 1, :] = results.squeeze(1)

# %%
outputs.size()
# Out:
# torch.Size([32, 12, 1])

# %%
results.squeeze(1)
# Out:
# tensor([[0.6007],
#         [0.7732],
#         [0.0893],
#         [0.5034],
#         [0.6295],
#         [0.0021],
#         [0.1592],
#         [0.5876],
#         [0.9847],
#         [0.4510],
#         [0.5795],
#         [0.2514],
#         [0.7494],
#         [0.7372],
#         [0.2176],
#         [0.0455],
#         [0.3082],
#         [0.3920],
#         [0.6706],
#         [0.2291],
#         [0.6425],
#         [0.3638],
#         [0.2226],
#         [0.6088],
#         [0.8872],
#         [0.6808],
#         [0.9987],
#         [0.6905],
#         [0.3058],
#         [0.7653],
#         [0.1394],
#         [0.5845]])

# %%
outputs
# Out:
# tensor([[[0.0000],
#          [0.6007],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000]],
#
#         [[0.0000],
#          [0.7732],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000]],
#
#         [[0.0000],
#          [0.0893],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000]],
#
#         [[0.0000],
#          [0.5034],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
#          [0.0000],
# ...

# %%
outputs = torch.zeros(32)
outputs.size()
# Out:
# torch.Size([32])

# %%
outputs = outputs.unsqueeze(1).unsqueeze(1)
outputs.size()
# Out:
# torch.Size([32, 1, 1])
